# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv(r'Data1.csv',index_col=0, parse_dates=True)

# %%
df.head()
# Out:
#              theta_1   theta_2   theta_3   theta_4   theta_5   theta_6
# 2017-01-01  0.756936 -1.467790  0.096136 -0.115306 -0.447908  0.902579
# 2017-01-02  0.767089  0.185797 -1.428536 -0.086443 -0.954288  1.930909
# 2017-01-03  0.404544  1.415887  0.443466  0.000200 -0.892351  2.449691
# 2017-01-04  1.313957 -1.804471 -0.836986  0.011785 -1.012518  1.182085
# 2017-01-05  0.209862  1.315868  0.140993 -0.046473 -1.417092  1.742433

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'theta_1'}>,
#         <AxesSubplot:title={'center':'theta_2'}>],
#        [<AxesSubplot:title={'center':'theta_3'}>,
#         <AxesSubplot:title={'center':'theta_4'}>],
#        [<AxesSubplot:title={'center':'theta_5'}>,
#         <AxesSubplot:title={'center':'theta_6'}>]], dtype=object)

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_2018=df.loc['2018-01-01':'2018-12-01',['theta_1','theta_4']]
df_2018.head()
# Out:
#              theta_1   theta_4
# 2018-01-01  0.682693 -0.238530
# 2018-01-02 -0.283107  0.158031
# 2018-01-03  1.572221  0.041347
# 2018-01-04 -1.042981  0.064832
# 2018-01-05 -1.392614 -0.015025

# %%
df_2018.plot()
# Out:
# <AxesSubplot:>

# %%
df_2018.hist()
# Out:
# array([[<AxesSubplot:title={'center':'theta_1'}>,
#         <AxesSubplot:title={'center':'theta_4'}>]], dtype=object)

# %%
df_2018.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
